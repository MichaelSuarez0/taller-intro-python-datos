# %% [markdown]
# # Sesión 2: Manejo de datos con Pandas

# %% [markdown]
# ## Índice
#
# 1. [Lectura de archivos Excel y CSV](#lectura-de-archivos)
#    - [Manejo de rutas con Pathlib](#manejo-de-rutas-con-pathlib)
# 2. [Manejo de datos con Pandas](#manejo-de-datos-con-pandas)
#    - [3.1 DataFrame](#31-dataframe-generation)
#    - [3.2 Indexing](#32-indexing)
#    - [3.3 Filtering Data](#33-filtering-data)
#    - [3.6 Groupby](#36-groupby)
#    - [3.7 Merge](#37-merge)
#    - [3.8 Reshape](#38-reshape)
# 3. [Limpieza y organización de datos](#limpieza-y-organización-de-datos)
#    - [3.1 Rename](#34-rename)
#    - [3.2 Dealing with Nulls](#34-dealing-with-nulls)
#    - [3.3 Duplicates](#35-duplicates)
# 4. [Estadísticas descriptivas básicas](#estadísticas-descriptivas-básicas)
#    - [4.1 Media](#35-duplicates)
#    - [4.2 Moda](#35-duplicates)
#    - [4.3 Mediana](#35-duplicates)
#    - [4.3 Desviación estándar](#35-duplicates)
